# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
zomato_data = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/zomato.csv', encoding='latin1')

# %%
zomato_data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
country_code_data = pd.read_excel(r'C:\Users\Admin\OneDrive\Desktop\Country-Code.xlsx')
country_code_data.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
zomato_data.shape
# Out:
# (9551, 21)

# %%
country_code_data.shape
# Out:
# (15, 2)

# %%
# Step 2: Merge datasets
merged_data = pd.merge(zomato_data, country_code_data, on='Country Code', how='inner')

# %%
merged_data.shape
# Out:
# (9551, 22)

# %%
merged_data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
merged_data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
# Step 3: Data preprocessing (Cleaning, Feature Engineering, Encoding)

# %%
merged_data.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
merged_data['Cuisines'].fillna(merged_data['Cuisines'].mode()[0], inplace=True)

# %%
merged_data['Average Cost for two'].fillna(merged_data['Average Cost for two'].mean(), inplace=True)

# %%
merged_data = merged_data.dropna()

# %%
merged_data.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9551 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# Convert columns to appropriate data types
merged_data['Has Table booking'] = merged_data['Has Table booking'].map({'yes': 1, 'no': 0})

merged_data['Has Online delivery'] = merged_data['Has Online delivery'].map({'yes': 1, 'no': 0})

merged_data['Is delivering now'] = merged_data['Is delivering now'].map({'yes': 1, 'no': 0})

merged_data['Switch to order menu'] = merged_data['Switch to order menu'].map({'yes': 1, 'no': 0})

# Check the unique values in 'Rating color' and 'Rating text' columns to decide further actions
print("Unique values in 'Rating color':", merged_data['Rating color'].unique())

print("Unique values in 'Rating text':", merged_data['Rating text'].unique())


rating_color_mapping = {'Green': 3, 'Yellow': 2, 'Orange': 1, 'White': 0}

merged_data['Rating color'] = merged_data['Rating color'].map(rating_color_mapping)

rating_text_mapping = {'Excellent': 5, 'Very Good': 4, 'Good': 3, 'Average': 2, 'Poor': 1}

merged_data['Rating text'] = merged_data['Rating text'].map(rating_text_mapping)


print(merged_data.dtypes)
# Out:
# Unique values in 'Rating color': ['Dark Green' 'Green' 'Yellow' 'Orange' 'White' 'Red']
# Unique values in 'Rating text': ['Excellent' 'Very Good' 'Good' 'Average' 'Not rated' 'Poor']
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking       float64
# Has Online delivery     float64
# Is delivering now       float64
# Switch to order menu    float64
# Price range               int64
# Aggregate rating        float64
# Rating color            float64
# Rating text             float64
# Votes                     int64
# Country                  object
# dtype: object

# %%
merged_data.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Has Table booking  Has Online delivery  \
# count           9551.000000                0.0                  0.0
# mean            1199.210763                NaN                  NaN
# std            16121.183073                NaN                  NaN
# min                0.000000                NaN                  NaN
# 25%              250.000000                NaN                  NaN
# ...

# %%
# EDA

# %%
country_restaurant_count = merged_data['Country'].value_counts()
country_restaurant_count.plot(kind='bar', figsize=(10, 6))
plt.title('Number of Restaurants by Country')
plt.xlabel('Country')
plt.ylabel('Number of Restaurants')
plt.xticks(rotation=45)
plt.show()

# %%
merged_data['Average Cost for two'].hist(bins=30, figsize=(10, 6))
plt.title('Histogram of Average Cost for Two')
plt.xlabel('Average Cost for Two')
plt.ylabel('Frequency')
plt.show()

# %%
price_range_distribution = merged_data['Price range'].value_counts()
price_range_distribution.plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8))
plt.title('Price Range Distribution')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(merged_data['Longitude'], merged_data['Latitude'], alpha=0.5)
plt.title('Scatter Plot of Restaurants (Longitude vs. Latitude)')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='Country', y='Aggregate rating', data=merged_data)
plt.title('Box Plot of Aggregate Rating by Country')
plt.xticks(rotation=90)
plt.show()

# %%
rating_text_count = merged_data['Rating text'].value_counts()
rating_text_count.plot(kind='bar', figsize=(10, 6))
plt.title('Number of Restaurants by Rating Text')
plt.xlabel('Rating Text')
plt.ylabel('Number of Restaurants')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(merged_data['Votes'], merged_data['Aggregate rating'], alpha=0.5)
plt.title('Scatter Plot of Restaurants (Votes vs. Aggregate Rating)')
plt.xlabel('Votes')
plt.ylabel('Aggregate Rating')
plt.grid(True)
plt.show()

# %%
currency_count = merged_data['Currency'].value_counts()
currency_count.plot(kind='bar', figsize=(10, 6))
plt.title('Number of Restaurants by Currency')
plt.xlabel('Currency')
plt.ylabel('Number of Restaurants')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import mean_squared_error, accuracy_score

# %%
# Encoding Categorical Variables
le = LabelEncoder()
merged_data['Rating color'] = le.fit_transform(merged_data['Rating color'])
merged_data['Rating text'] = le.fit_transform(merged_data['Rating text'])

# Select features and target variables
features = merged_data[['Longitude', 'Latitude', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Aggregate rating', 'Votes', 'Rating color', 'Rating text']]
target_average_cost = merged_data['Average Cost for two']
target_price_range = merged_data['Price range']

#  Data Split
X_train, X_test, y_train_average_cost, y_test_average_cost, y_train_price_range, y_test_price_range = train_test_split(
    features, target_average_cost, target_price_range, test_size=0.2, random_state=42
)

#  Data Imputation for Handling Missing Values
imputer = SimpleImputer(strategy='mean')  
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

#  Data Standardization
scaler = StandardScaler()
X_train_standardized = scaler.fit_transform(X_train_imputed)
X_test_standardized = scaler.transform(X_test_imputed)

#  Build  Models
models = {
    'Linear Regression': LinearRegression(),
    'Decision Tree Regressor': DecisionTreeRegressor(),
    'Random Forest Regressor': RandomForestRegressor(),
    'Logistic Regression': LogisticRegression(),
    'Random Forest Classifier': RandomForestClassifier()
}

for model_name, model in models.items():
    # For regression models
    if 'Regressor' in model_name:
        model.fit(X_train_standardized, y_train_average_cost)
        train_score = model.score(X_train_standardized, y_train_average_cost) * 100
        test_score = model.score(X_test_standardized, y_test_average_cost) * 100
        print(f"{model_name}: Train Score - {train_score:.2f}%, Test Score - {test_score:.2f}%")

    # For classification models
    elif 'Classifier' in model_name:
        model.fit(X_train_standardized, y_train_price_range)
        y_pred = model.predict(X_test_standardized)
        accuracy = accuracy_score(y_test_price_range, y_pred) * 100
        print(f"{model_name}: Accuracy - {accuracy:.2f}%")
# Out:
# Decision Tree Regressor: Train Score - 100.00%, Test Score - 48.06%
# Random Forest Regressor: Train Score - 92.72%, Test Score - 53.13%
# Random Forest Classifier: Accuracy - 55.10%

# %%
from sklearn.model_selection import GridSearchCV


models = {
    
    'Tuned Random Forest Regressor': RandomForestRegressor()
}

# Hyperparameter tuning for RandomForestRegressor
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(RandomForestRegressor(), param_grid, cv=5)
grid_search.fit(X_train_standardized, y_train_average_cost)
best_rf_model = grid_search.best_estimator_

# Evaluate the tuned model
train_score = best_rf_model.score(X_train_standardized, y_train_average_cost) * 100
test_score = best_rf_model.score(X_test_standardized, y_test_average_cost) * 100
print(f"Tuned Random Forest Regressor: Train Score - {train_score:.2f}%, Test Score - {test_score:.2f}%")
# Out:
# Tuned Random Forest Regressor: Train Score - 79.15%, Test Score - 58.44%
